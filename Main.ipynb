# %% [markdown]
# # Parkinson's Freezing of Gait Prediction

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import random
import numpy as np
import os
import random
from sklearn import preprocessing

import gymnasium as gym
from gymnasium import spaces

from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO, A2C
from stable_baselines3.common.env_util import make_vec_env

# %%
TDCSFOG_DIR = "./dataset/train/tdcsfog/"

# %% [markdown]
# #### Helper Functions

# %%
def choose_random_file(directory):
  file_names = [f for f in os.listdir(directory) if f.endswith('.csv')]
  random_file_name = random.choice(file_names)
  return os.path.join(directory, random_file_name)

def normalize_column(df, column_name):
    min_val = df[column_name].min()
    max_val = df[column_name].max()
    df[column_name] = 2 * (df[column_name] - min_val) / (max_val - min_val) - 1

# %% [markdown]
# ### Custom Environment

# %%
class ParkinsonsEnvironment(gym.Env):
    metadata = {"render_modes": ["console"]}
    
    def __init__(self, render_mode=None):
        super(ParkinsonsEnvironment, self).__init__()

        # Choose a random episode from tdcsfog data
        random_episode_dataset_path = choose_random_file(TDCSFOG_DIR)
        episode_dataframe = pd.read_csv(random_episode_dataset_path)

        # Normalize AccV, AccML, AccAP columns
        normalize_column(episode_dataframe, 'AccV')
        normalize_column(episode_dataframe, 'AccML')
        normalize_column(episode_dataframe, 'AccAP')

        
        self.episode_dataframe = episode_dataframe
        self.timestep = 0
        self.end_timestep = self.episode_dataframe.shape[0]-1
        self.render_mode = render_mode
        self.action_space = spaces.MultiBinary(3)
        self.observation_space = spaces.Box(low=-1, high=1, shape=(3,), dtype=np.float64)

    def step(self, action):
        current_state = self.episode_dataframe.iloc[self.timestep].to_numpy()
        
        observation = current_state[1:4] # Values of AccV, AccML and AccAP
        reward = 0
        terminated = False
        truncated = False
        info = {}
        
        if self.timestep == self.end_timestep:
            terminated = True
        
        actual_action = current_state[4:] # Values of StartHesitation, Turn and Walking

        # Calculate reward
        diff = np.absolute(action - actual_action).sum()
        reward = 0
        if 1 in actual_action:
            if diff == 0:
                reward = 1/self.timestep
            else:
                reward = -1/self.timestep
        else:
            if diff == 0:
                reward = 1 / self.end_timestep
            else:
                reward = -1 / self.end_timestep
        self.timestep += 1 # Increase timestep
        
        return observation, reward, terminated, truncated, info

    def reset(self, seed=None, options=None):
        super().reset(seed=seed, options=options)

        # Choose a random episode from tdcsfog data
        random_episode_dataset_path = choose_random_file(TDCSFOG_DIR)
        episode_dataframe = pd.read_csv(random_episode_dataset_path)

        # Normalize AccV, AccML, AccAP columns
        normalize_column(episode_dataframe, 'AccV')
        normalize_column(episode_dataframe, 'AccML')
        normalize_column(episode_dataframe, 'AccAP')
        
        self.episode_dataframe = episode_dataframe
        self.timestep = 0
        self.end_timestep = self.episode_dataframe.shape[0]-1
        
        observation = self.episode_dataframe.iloc[0, 1:4].to_numpy()
        info = {}
        
        return observation, info

    def render(self):
        if self.render_mode != "console":
            return
        current_state = self.episode_dataframe.iloc[self.timestep].to_numpy()
        obs = current_state[1:4]
        print(f"AccV: {obs[0]}, AccML: {obs[1]}, AccAP: {obs[2]}")

    def close(self):
        pass

# %% [markdown]
# ### Validating the environment

# %%
env = ParkinsonsEnvironment()
check_env(env, warn=True)

# %% [markdown]
# ### Testing the environment

# %%
env = ParkinsonsEnvironment()

obs, _ = env.reset()
env.render()

n_steps = 10
for step in range(n_steps):
    step+=1
    print()
    print(f"Step {step}")
    action_taken = env.action_space.sample()
    print("Action:", action_taken)
    obs, reward, terminated, truncated, info = env.step(action_taken)
    done = terminated or truncated
    print("Reward:", reward)
    print()
    env.render()
    if done:
        break
# Out:
# Step 1
# Action: [0 1 0]
# Reward: -0.00020004000800160032
#
#
# Step 2
# Action: [1 1 1]
# Reward: -0.00020004000800160032
#
#
# Step 3
# Action: [1 1 1]
# Reward: -0.00020004000800160032
#
#
# Step 4
# Action: [0 0 0]
# Reward: 0.00020004000800160032
#
#
# Step 5
# Action: [1 1 0]
# Reward: -0.00020004000800160032
#
#
# Step 6
# Action: [0 1 0]
# Reward: -0.00020004000800160032
#
#
# Step 7
# Action: [1 0 1]
# Reward: -0.00020004000800160032
#
#
# Step 8
# Action: [0 0 1]
# Reward: -0.00020004000800160032
#
#
# Step 9
# Action: [1 0 1]
# Reward: -0.00020004000800160032
#
#
# Step 10
# Action: [1 0 1]
# Reward: -0.00020004000800160032

# %% [markdown]
# ### Applying

# %%
# Initializing the Environment

vec_env = make_vec_env(ParkinsonsEnvironment)

# %%
model = PPO("MlpPolicy", env, verbose=1,
            tensorboard_log="./parkinsons_tensorboard/")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1_000_000, tb_log_name="PPO")
# Out:
# Logging to ./parkinsons_tensorboard/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 5653 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4235         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0054430906 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0104      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00532     |
# |    value_loss           | 0.000691     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.47e+03     |
# |    ep_rew_mean          | -0.732       |
# | time/                   |              |
# |    fps                  | 3980         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0066658827 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.07        |
# |    explained_variance   | -1.41        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0229       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00739     |
# |    value_loss           | 0.000267     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.47e+03    |
# |    ep_rew_mean          | -0.732      |
# | time/                   |             |
# |    fps                  | 3858        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015951218 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00844    |
# |    value_loss           | 4.61e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.47e+03    |
# |    ep_rew_mean          | -0.732      |
# | time/                   |             |
# |    fps                  | 3767        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009668082 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | -0.051      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0296     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0072     |
# |    value_loss           | 4.69e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.51e+03     |
# |    ep_rew_mean          | -0.722       |
# | time/                   |              |
# |    fps                  | 3715         |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0078104124 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.97        |
# |    explained_variance   | -3.84        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0173      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00631     |
# |    value_loss           | 1.06e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.51e+03    |
# |    ep_rew_mean          | -0.722      |
# | time/                   |             |
# |    fps                  | 3700        |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015828954 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0217     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00716    |
# |    value_loss           | 2.76e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.51e+03    |
# |    ep_rew_mean          | -0.722      |
# | time/                   |             |
# |    fps                  | 3679        |
# |    iterations           | 8           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011347733 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | -1.92       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00559     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00878    |
# |    value_loss           | 2.01e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.62e+03    |
# |    ep_rew_mean          | -0.758      |
# | time/                   |             |
# |    fps                  | 3664        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008333627 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | -6.52       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0167     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00676    |
# |    value_loss           | 2.71e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.62e+03    |
# |    ep_rew_mean          | -0.758      |
# | time/                   |             |
# |    fps                  | 3646        |
# |    iterations           | 10          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008373592 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0217     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 2.56e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.62e+03    |
# |    ep_rew_mean          | -0.758      |
# | time/                   |             |
# |    fps                  | 3642        |
# |    iterations           | 11          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010535503 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | -3.66       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0218     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 6.47e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.91e+03     |
# |    ep_rew_mean          | -0.752       |
# | time/                   |              |
# |    fps                  | 3635         |
# |    iterations           | 12           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0088101085 |
# |    clip_fraction        | 0.0882       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.97        |
# |    explained_variance   | -1.52        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0277      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00755     |
# |    value_loss           | 8.21e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.91e+03    |
# |    ep_rew_mean          | -0.752      |
# | time/                   |             |
# |    fps                  | 3633        |
# |    iterations           | 13          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009469381 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 1.61e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.91e+03    |
# |    ep_rew_mean          | -0.752      |
# | time/                   |             |
# |    fps                  | 3631        |
# |    iterations           | 14          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008340156 |
# |    clip_fraction        | 0.0836      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | -1.24       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0131      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00803    |
# |    value_loss           | 2.41e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.86e+03    |
# |    ep_rew_mean          | -0.731      |
# | time/                   |             |
# |    fps                  | 3610        |
# |    iterations           | 15          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009081537 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -2.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 2e-06       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.86e+03     |
# |    ep_rew_mean          | -0.731       |
# | time/                   |              |
# |    fps                  | 3607         |
# |    iterations           | 16           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0121868765 |
# |    clip_fraction        | 0.179        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | -0.0575      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0123      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0152      |
# |    value_loss           | 1.03e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.86e+03    |
# |    ep_rew_mean          | -0.731      |
# | time/                   |             |
# |    fps                  | 3606        |
# |    iterations           | 17          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015536267 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | -1.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0545      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 7.17e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.86e+03    |
# |    ep_rew_mean          | -0.731      |
# | time/                   |             |
# |    fps                  | 3604        |
# |    iterations           | 18          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.021501208 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | -0.0795     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0495     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 3.86e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.16e+03    |
# |    ep_rew_mean          | -0.65       |
# | time/                   |             |
# |    fps                  | 3601        |
# |    iterations           | 19          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.024882376 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.00874     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0377     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 4.89e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.16e+03    |
# |    ep_rew_mean          | -0.65       |
# | time/                   |             |
# |    fps                  | 3599        |
# |    iterations           | 20          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.022916231 |
# |    clip_fraction        | 0.444       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.0687     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0263     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 1.47e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.16e+03     |
# |    ep_rew_mean          | -0.65        |
# | time/                   |              |
# |    fps                  | 3594         |
# |    iterations           | 21           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0029689218 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.0379       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00491     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 4.77e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.16e+03    |
# |    ep_rew_mean          | -0.65       |
# | time/                   |             |
# |    fps                  | 3592        |
# |    iterations           | 22          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016526593 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.591      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00807    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 3.81e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.61e+03    |
# |    ep_rew_mean          | -0.667      |
# | time/                   |             |
# |    fps                  | 3584        |
# |    iterations           | 23          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010892142 |
# |    clip_fraction        | 0.0954      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | -0.0844     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0039     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00919    |
# |    value_loss           | 1.6e-06     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.61e+03    |
# |    ep_rew_mean          | -0.667      |
# | time/                   |             |
# |    fps                  | 3583        |
# |    iterations           | 24          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.026262585 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 0.0845      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0472     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0247     |
# |    value_loss           | 5.71e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.61e+03     |
# |    ep_rew_mean          | -0.667       |
# | time/                   |              |
# |    fps                  | 3580         |
# |    iterations           | 25           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0031938704 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.809       |
# |    explained_variance   | -0.0188      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0149      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 6.68e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.6e+03     |
# |    ep_rew_mean          | -0.533      |
# | time/                   |             |
# |    fps                  | 3576        |
# |    iterations           | 26          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013987573 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.656      |
# |    explained_variance   | -1.22       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00726    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 5.56e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.6e+03     |
# |    ep_rew_mean          | -0.533      |
# | time/                   |             |
# |    fps                  | 3571        |
# |    iterations           | 27          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007787749 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.54       |
# |    explained_variance   | -0.179      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00372    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 9.59e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.35e+03     |
# |    ep_rew_mean          | -0.378       |
# | time/                   |              |
# |    fps                  | 3563         |
# |    iterations           | 28           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0064448453 |
# |    clip_fraction        | 0.0643       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | -0.0737      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00684     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 7.61e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.35e+03    |
# |    ep_rew_mean          | -0.378      |
# | time/                   |             |
# |    fps                  | 3564        |
# |    iterations           | 29          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.013600944 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.284      |
# |    explained_variance   | 0.0513      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0236      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00751    |
# |    value_loss           | 7.87e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.35e+03     |
# |    ep_rew_mean          | -0.378       |
# | time/                   |              |
# |    fps                  | 3560         |
# |    iterations           | 30           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0014503917 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -0.000157    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00226     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 2.77e-05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.35e+03      |
# |    ep_rew_mean          | -0.378        |
# | time/                   |               |
# |    fps                  | 3560          |
# |    iterations           | 31            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00071280333 |
# |    clip_fraction        | 0.0203        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.234        |
# |    explained_variance   | -0.0666       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000175      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00226      |
# |    value_loss           | 5.34e-06      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.35e+03   |
# |    ep_rew_mean          | -0.378     |
# | time/                   |            |
# |    fps                  | 3561       |
# |    iterations           | 32         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00188873 |
# |    clip_fraction        | 0.0191     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.234     |
# |    explained_variance   | -0.26      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00724   |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00169   |
# |    value_loss           | 3.28e-06   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.73e+03     |
# |    ep_rew_mean          | -0.358       |
# | time/                   |              |
# |    fps                  | 3560         |
# |    iterations           | 33           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0011630382 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | -2.45        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.009       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 2.48e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.73e+03     |
# |    ep_rew_mean          | -0.358       |
# | time/                   |              |
# |    fps                  | 3561         |
# |    iterations           | 34           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0057597267 |
# |    clip_fraction        | 0.0577       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.307       |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00423      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00606     |
# |    value_loss           | 8e-07        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.73e+03     |
# |    ep_rew_mean          | -0.358       |
# | time/                   |              |
# |    fps                  | 3561         |
# |    iterations           | 35           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0010142033 |
# |    clip_fraction        | 0.00522      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.171       |
# |    explained_variance   | -0.178       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00586     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 2.13e-05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.73e+03      |
# |    ep_rew_mean          | -0.358        |
# | time/                   |               |
# |    fps                  | 3562          |
# |    iterations           | 36            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00025771098 |
# |    clip_fraction        | 0.00718       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.153        |
# |    explained_variance   | -0.242        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0044       |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000785     |
# |    value_loss           | 5.45e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.82e+03     |
# |    ep_rew_mean          | -0.392       |
# | time/                   |              |
# |    fps                  | 3562         |
# |    iterations           | 37           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0005567594 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.191       |
# |    explained_variance   | -0.0818      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00154     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000726    |
# |    value_loss           | 4.24e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.82e+03     |
# |    ep_rew_mean          | -0.392       |
# | time/                   |              |
# |    fps                  | 3563         |
# |    iterations           | 38           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0011572926 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.168       |
# |    explained_variance   | -0.505       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0112      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 7.52e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.82e+03     |
# |    ep_rew_mean          | -0.392       |
# | time/                   |              |
# |    fps                  | 3562         |
# |    iterations           | 39           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0022290375 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0892      |
# |    explained_variance   | -0.246       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00792     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0052      |
# |    value_loss           | 3.51e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.69e+03    |
# |    ep_rew_mean          | -0.279      |
# | time/                   |             |
# |    fps                  | 3561        |
# |    iterations           | 40          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.001004782 |
# |    clip_fraction        | 0.00977     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0768     |
# |    explained_variance   | -1.6        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 4.31e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.42e+03     |
# |    ep_rew_mean          | -0.183       |
# | time/                   |              |
# |    fps                  | 3561         |
# |    iterations           | 41           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0017245415 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0599      |
# |    explained_variance   | -0.237       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00885     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 1.18e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.42e+03     |
# |    ep_rew_mean          | -0.183       |
# | time/                   |              |
# |    fps                  | 3561         |
# |    iterations           | 42           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0013561007 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0554      |
# |    explained_variance   | 0.446        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00252     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 1.04e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.42e+03     |
# |    ep_rew_mean          | -0.183       |
# | time/                   |              |
# |    fps                  | 3562         |
# |    iterations           | 43           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0007692445 |
# |    clip_fraction        | 0.00654      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.054       |
# |    explained_variance   | -0.388       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000813    |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 3e-07        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.35e+03     |
# |    ep_rew_mean          | -0.101       |
# | time/                   |              |
# |    fps                  | 3561         |
# |    iterations           | 44           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0005729974 |
# |    clip_fraction        | 0.00786      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0552      |
# |    explained_variance   | -1.68        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00125      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 1.87e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.35e+03      |
# |    ep_rew_mean          | -0.101        |
# | time/                   |               |
# |    fps                  | 3561          |
# |    iterations           | 45            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00016005468 |
# |    clip_fraction        | 0.00166       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0503       |
# |    explained_variance   | 0.756         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.85e-05      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000367     |
# |    value_loss           | 1.27e-06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.35e+03      |
# |    ep_rew_mean          | -0.101        |
# | time/                   |               |
# |    fps                  | 3562          |
# |    iterations           | 46            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 4.1942094e-05 |
# |    clip_fraction        | 0.00083       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0188       |
# |    explained_variance   | -0.00498      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.7e-07       |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.00017      |
# |    value_loss           | 1.33e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.35e+03     |
# |    ep_rew_mean          | -0.101       |
# | time/                   |              |
# |    fps                  | 3562         |
# |    iterations           | 47           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 2.348724e-05 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.019       |
# |    explained_variance   | 0.00352      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -8.62e-06    |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -4.58e-05    |
# |    value_loss           | 8.36e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.5e+03       |
# |    ep_rew_mean          | -0.0617       |
# | time/                   |               |
# |    fps                  | 3561          |
# |    iterations           | 48            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00022645964 |
# |    clip_fraction        | 0.00459       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.023        |
# |    explained_variance   | -0.137        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00561      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000625     |
# |    value_loss           | 1.93e-06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.5e+03       |
# |    ep_rew_mean          | -0.0617       |
# | time/                   |               |
# |    fps                  | 3561          |
# |    iterations           | 49            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00018183827 |
# |    clip_fraction        | 0.00186       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0229       |
# |    explained_variance   | 0.341         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.01e-05      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000789     |
# |    value_loss           | 6.7e-07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.5e+03       |
# |    ep_rew_mean          | -0.0617       |
# | time/                   |               |
# |    fps                  | 3562          |
# |    iterations           | 50            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 4.3968146e-05 |
# |    clip_fraction        | 0.000488      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0142       |
# |    explained_variance   | -0.0148       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.34e-05      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.0002       |
# |    value_loss           | 2.89e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.5e+03      |
# |    ep_rew_mean          | -0.0617      |
# | time/                   |              |
# |    fps                  | 3562         |
# |    iterations           | 51           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0026512612 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0236      |
# |    explained_variance   | -0.659       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0431       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 2.57e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58e+03     |
# |    ep_rew_mean          | -0.0128      |
# | time/                   |              |
# |    fps                  | 3562         |
# |    iterations           | 52           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0012116339 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0807      |
# |    explained_variance   | -1.53        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0061      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00247     |
# |    value_loss           | 1.89e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58e+03     |
# |    ep_rew_mean          | -0.0128      |
# | time/                   |              |
# |    fps                  | 3562         |
# |    iterations           | 53           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0011519905 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0856      |
# |    explained_variance   | 0.413        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00579     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000694    |
# |    value_loss           | 1.74e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.41e+03     |
# |    ep_rew_mean          | 0.0398       |
# | time/                   |              |
# |    fps                  | 3561         |
# |    iterations           | 54           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0027959351 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.178       |
# |    explained_variance   | -0.151       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00137     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00672     |
# |    value_loss           | 8.82e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.41e+03     |
# |    ep_rew_mean          | 0.0398       |
# | time/                   |              |
# |    fps                  | 3562         |
# |    iterations           | 55           |
# |    time_elapsed         | 31           |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 8.14e+03    |
# |    ep_rew_mean          | 0.482       |
# | time/                   |             |
# |    fps                  | 3504        |
# |    iterations           | 472         |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.021238461 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.0726      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.023      |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.0279     |
# |    value_loss           | 2.27e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.14e+03    |
# |    ep_rew_mean          | 0.482       |
# | time/                   |             |
# |    fps                  | 3504        |
# |    iterations           | 473         |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.021220243 |
# |    clip_fraction        | 0.411       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | 0.0552      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0439     |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 7.46e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.14e+03    |
# |    ep_rew_mean          | 0.482       |
# | time/                   |             |
# |    fps                  | 3503        |
# |    iterations           | 474         |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.018275551 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.66       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0308     |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.0331     |
# |    value_loss           | 1.23e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.14e+03    |
# |    ep_rew_mean          | 0.482       |
# | time/                   |             |
# |    fps                  | 3504        |
# |    iterations           | 475         |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.017897673 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.0135      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0355     |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.035      |
# |    value_loss           | 1.55e-08    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.14e+03   |
# |    ep_rew_mean          | 0.482      |
# | time/                   |            |
# |    fps                  | 3503       |
# |    iterations           | 476        |
# |    time_elapsed         | 278        |
# |    total_timesteps      | 974848     |
# | train/                  |            |
# |    approx_kl            | 0.01315913 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.531     |
# |    explained_variance   | 0.394      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.028     |
# |    n_updates            | 4750       |
# |    policy_gradient_loss | -0.0171    |
# |    value_loss           | 2.18e-07   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.14e+03     |
# |    ep_rew_mean          | 0.482        |
# | time/                   |              |
# |    fps                  | 3504         |
# |    iterations           | 477          |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0071362383 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.438       |
# |    explained_variance   | 0.439        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0282      |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.0166      |
# |    value_loss           | 1.6e-08      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.14e+03    |
# |    ep_rew_mean          | 0.482       |
# | time/                   |             |
# |    fps                  | 3504        |
# |    iterations           | 478         |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.008624316 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.433      |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 1.12e-08    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.14e+03  |
# |    ep_rew_mean          | 0.482     |
# | time/                   |           |
# |    fps                  | 3504      |
# |    iterations           | 479       |
# |    time_elapsed         | 279       |
# |    total_timesteps      | 980992    |
# | train/                  |           |
# |    approx_kl            | 0.0103906 |
# |    clip_fraction        | 0.126     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.284    |
# |    explained_variance   | -0.081    |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00909  |
# |    n_updates            | 4780      |
# |    policy_gradient_loss | -0.0152   |
# |    value_loss           | 1.16e-08  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.14e+03    |
# |    ep_rew_mean          | 0.482       |
# | time/                   |             |
# |    fps                  | 3504        |
# |    iterations           | 480         |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.006699239 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.252      |
# |    explained_variance   | -1.22       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0094     |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 3.27e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.14e+03     |
# |    ep_rew_mean          | 0.482        |
# | time/                   |              |
# |    fps                  | 3504         |
# |    iterations           | 481          |
# |    time_elapsed         | 281          |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0037758409 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.205       |
# |    explained_variance   | -0.0973      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0363      |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | -0.0128      |
# |    value_loss           | 5.39e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.14e+03    |
# |    ep_rew_mean          | 0.482       |
# | time/                   |             |
# |    fps                  | 3504        |
# |    iterations           | 482         |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.020924231 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.101      |
# |    explained_variance   | -0.558      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.00926    |
# |    value_loss           | 8.59e-09    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.14e+03     |
# |    ep_rew_mean          | 0.482        |
# | time/                   |              |
# |    fps                  | 3504         |
# |    iterations           | 483          |
# |    time_elapsed         | 282          |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0016683051 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.106       |
# |    explained_variance   | -1.06        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00264      |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 3.2e-08      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.14e+03      |
# |    ep_rew_mean          | 0.482         |
# | time/                   |               |
# |    fps                  | 3505          |
# |    iterations           | 484           |
# |    time_elapsed         | 282           |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 0.00041972363 |
# |    clip_fraction        | 0.00386       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0721       |
# |    explained_variance   | -0.0188       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000655     |
# |    n_updates            | 4830          |
# |    policy_gradient_loss | -0.000978     |
# |    value_loss           | 2.75e-08      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.14e+03    |
# |    ep_rew_mean          | 0.482       |
# | time/                   |             |
# |    fps                  | 3505        |
# |    iterations           | 485         |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.002296676 |
# |    clip_fraction        | 0.026       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.137      |
# |    explained_variance   | -0.767      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00679    |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00127    |
# |    value_loss           | 8.11e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.79e+03     |
# |    ep_rew_mean          | 0.44         |
# | time/                   |              |
# |    fps                  | 3505         |
# |    iterations           | 486          |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0020409063 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0838      |
# |    explained_variance   | 0.0199       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000339    |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00044     |
# |    value_loss           | 8.01e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.79e+03     |
# |    ep_rew_mean          | 0.44         |
# | time/                   |              |
# |    fps                  | 3505         |
# |    iterations           | 487          |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0037483429 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.175       |
# |    explained_variance   | 0.384        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0124      |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 6.58e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.79e+03     |
# |    ep_rew_mean          | 0.44         |
# | time/                   |              |
# |    fps                  | 3505         |
# |    iterations           | 488          |
# |    time_elapsed         | 285          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0009936688 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.221       |
# |    explained_variance   | 0.0183       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00259      |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.000605    |
# |    value_loss           | 2.15e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.79e+03     |
# |    ep_rew_mean          | 0.44         |
# | time/                   |              |
# |    fps                  | 3505         |
# |    iterations           | 489          |
# |    time_elapsed         | 285          |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0020378144 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | -0.925       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0041      |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.000534    |
# |    value_loss           | 1.19e-06     |
# ------------------------------------------

# %%
model.save("ppo_model.pkl")

# %% [markdown]
# ### Prediction

# %%
ppo_model = PPO.load("ppo_model.pkl")

# %%
test_data_dir = "./dataset/test/tdcsfog/003f117e14.csv"

# %%
test_df = pd.read_csv(test_data_dir)
test_df.head()
# Out:
#    Time      AccV     AccML     AccAP
# 0     0 -9.533939  0.566322 -1.413525
# 1     1 -9.536140  0.564137 -1.440621
# 2     2 -9.529345  0.561765 -1.429332
# 3     3 -9.531239  0.564227 -1.415490
# 4     4 -9.540825  0.561854 -1.429471

# %%
# normalize dataset

normalize_column(test_df, 'AccV')
normalize_column(test_df, 'AccML')
normalize_column(test_df, 'AccAP')

# %%
test_df.head()
# Out:
#    Time      AccV     AccML     AccAP
# 0     0  0.434787  0.280462 -0.326333
# 1     1  0.434565  0.280172 -0.329406
# 2     2  0.435249  0.279858 -0.328125
# 3     3  0.435058  0.280184 -0.326556
# 4     4  0.434094  0.279870 -0.328141

# %%
predicted_values = []

# %%
for i in range(len(test_df)):
    action, _ = model.predict(test_df.iloc[i, 1:4])
    predicted_values.append([f'003f117e14_{i}'] + list(action))

# %%
submission_df = pd.DataFrame(predicted_values, columns = ['id','StartHesitation', 'Turn', 'Walking'])

# %%
submission_df.head()
# Out:
#              id  StartHesitation  Turn  Walking
# 0  003f117e14_0              0.0   0.0      0.0
# 1  003f117e14_1              0.0   0.0      0.0
# 2  003f117e14_2              0.0   0.0      0.0
# 3  003f117e14_3              0.0   0.0      0.0
# 4  003f117e14_4              0.0   0.0      0.0

# %%
submission_df.to_csv('submission.csv', index=False)
